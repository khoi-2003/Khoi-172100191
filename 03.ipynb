# %%
#import
from PIL import Image
from imgtools import *

# %%
#đường dẫn hình ảnh
my_path = 'C:/Users/Admin/Documents/GTA San Andreas User Files/SAMP/screens/sa-mp-000.png'

# %%
#đọc ảnh
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1366x768>

# %%
print(img.size)
# Out:
# (1366, 768)

# %%
# Thay đổi kích thước
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
# Thay đổi kích thước
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=50x28>

# %%
directory = 'C:/Users/Admin/Documents/GTA San Andreas User Files/SAMP/screens'
new_img_03_path = directory + '/new_img03.png'
img.save(new_img_03_path)
